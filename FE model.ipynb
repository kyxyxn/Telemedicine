# %%
import numpy as np
import pandas as pd

# %%
amb_df = pd.read_csv(r'/Users/krhee/Dropbox (ASU)/Coding/RA_Coding/Utilization/amb-final-county.csv')
tele_df = pd.read_csv(r'/Users/krhee/Dropbox (ASU)/Coding/RA_Coding/providerservice/q3014_county_final.csv')

# %% [markdown]
# 맨 처음에는 county identifier 로만 된 DF: `year`, `fips`, `state`, `county`, `state_fips`, `county_fips`, `number_of_fee_for_service_beneficiaries`

# %%
temp_df = pd.merge(tele_df, amb_df, on=['year','fips'], how='outer')

# %%
temp_df.groupby(['fips'])
# Out:
#          year   fips  tot_benes  tot_srvcs  tot_bene_day_srvcs  \
# 0      2013.0  01021       61.0       66.0                66.0
# 1      2013.0  01069      467.0      976.0               976.0
# 2      2013.0  01073       47.0       85.0                85.0
# 3      2013.0  01101       12.0       14.0                14.0
# 4      2013.0  01127       49.0      110.0               110.0
# ...       ...    ...        ...        ...                 ...
# 16216  2018.0  56009        NaN        NaN                 NaN
# 16217  2015.0  20187        NaN        NaN                 NaN
# 16218  2017.0  31069        NaN        NaN                 NaN
# 16219  2018.0  08061        NaN        NaN                 NaN
# 16220  2018.0  30007        NaN        NaN                 NaN
#
#        tot_srvcs_chrg          reference_period state      county state_fips  \
# 0             1980.00                       NaN   NaN         NaN        NaN
# ...

# %%
ffs_df = temp_df[['year', 'fips', 'state', 'county', 'state_fips', 'county_fips', 'number_of_fee_for_service_beneficiaries']].drop_duplicates()
ffs_df = ffs_df[(ffs_df['year']<2019)&(ffs_df['year']>2013)].reset_index(drop=True)

# %%
ffs_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15510 entries, 0 to 15509
# Data columns (total 7 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   state_fips                               15510 non-null  object
#  1   year                                     15510 non-null  float64
#  2   state                                    15510 non-null  object
#  3   fips                                     15510 non-null  object
#  4   county                                   15510 non-null  object
#  5   county_fips                              15510 non-null  object
#  6   number_of_fee_for_service_beneficiaries  15510 non-null  float64
# dtypes: float64(2), object(5)
# memory usage: 969.4+ KB

# %%
ffs_df['state_fips'] = [str(i)[:2] for i in ffs_df['fips']]
ffs_df['county_fips'] = [str(i)[2:] for i in ffs_df['fips']]

# %%
ffs_df
# Out:
#          year   fips state      county state_fips county_fips  \
# 0      2013.0  01021   NaN         NaN         01         021
# 1      2013.0  01069   NaN         NaN         01         069
# 2      2013.0  01073   NaN         NaN         01         073
# 3      2013.0  01101   NaN         NaN         01         101
# 4      2013.0  01127   NaN         NaN         01         127
# ...       ...    ...   ...         ...        ...         ...
# 16216  2018.0  56009    WY    Converse         56         009
# 16217  2015.0  20187    KS     Stanton         20         187
# 16218  2017.0  31069    NE      Garden         31         069
# 16219  2018.0  08061    CO       Kiowa         08         061
# 16220  2018.0  30007    MT  Broadwater         30         007
#
#        number_of_fee_for_service_beneficiaries
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# ...

# %%
len(ffs_df), len()

# %%
ffs_df[['state_fips','year','state']].dropna().drop_duplicates()
# Out:
#       state_fips    year state
# 198           01  2014.0    AL
# 204           04  2014.0    AZ
# 207           05  2014.0    AR
# 209           06  2014.0    CA
# 215           08  2014.0    CO
# ...          ...     ...   ...
# 12515         50  2017.0    VT
# 12841         02  2018.0    AK
# 13227         15  2018.0    HI
# 14961         49  2018.0    UT
# 14986         50  2018.0    VT
#
# [255 rows x 3 columns]

# %%
1. st
# Out:
#          year   fips state      county state_fips county_fips  \
# 0      2013.0  01021   NaN         NaN         01         021
# 1      2013.0  01069   NaN         NaN         01         069
# 2      2013.0  01073   NaN         NaN         01         073
# 3      2013.0  01101   NaN         NaN         01         101
# 4      2013.0  01127   NaN         NaN         01         127
# ...       ...    ...   ...         ...        ...         ...
# 16216  2018.0  56009    WY    Converse         56         009
# 16217  2015.0  20187    KS     Stanton         20         187
# 16218  2017.0  31069    NE      Garden         31         069
# 16219  2018.0  08061    CO       Kiowa         08         061
# 16220  2018.0  30007    MT  Broadwater         30         007
#
#        number_of_fee_for_service_beneficiaries
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# ...

# %%
new_list = []
for i in range(len(tele_df)):
    if len(str(tele_df['fips'][i]))==4:
        new_list.append(str('0')+str(tele_df['fips'][i]))
    if len(str(tele_df['fips'][i]))==5:
        new_list.append(str(tele_df['fips'][i]))
tele_df['fips'] = new_list

# %%
amb_df['state_fips'] = amb_df['state_fips'].astype(int)
amb_df['county_fips'] = amb_df['county_fips'].astype(int)

new_list = []
for i in range(len(amb_df)):
    if len(str(amb_df['state_fips'][i]))==1:
        new_list.append(str('0')+str(amb_df['state_fips'][i]))
    if len(str(amb_df['state_fips'][i]))==2:
        new_list.append(str(amb_df['state_fips'][i]))
amb_df['state_fips'] = new_list

new_list = []
for i in range(len(amb_df)):
    if len(str(amb_df['county_fips'][i]))==1:
        new_list.append(str('00')+str(amb_df['county_fips'][i]))
    if len(str(amb_df['county_fips'][i]))==2:
        new_list.append(str('0')+str(amb_df['county_fips'][i]))
    if len(str(amb_df['county_fips'][i]))==3:
        new_list.append(str(amb_df['county_fips'][i]))
amb_df['county_fips'] = new_list


new_list = []
for i in range(len(amb_df)):
    if len(str(amb_df['fips'][i]))==4:
        new_list.append(str('0')+str(amb_df['fips'][i]))
    if len(str(amb_df['fips'][i]))==5:
        new_list.append(str(amb_df['fips'][i]))
amb_df['fips'] = new_list

# %%
temp_

# %%
temp_df
# Out:
#          year   fips  tot_benes  tot_srvcs  tot_bene_day_srvcs  \
# 0      2013.0  01021       61.0       66.0                66.0
# 1      2013.0  01069      467.0      976.0               976.0
# 2      2013.0  01073       47.0       85.0                85.0
# 3      2013.0  01101       12.0       14.0                14.0
# 4      2013.0  01127       49.0      110.0               110.0
# ...       ...    ...        ...        ...                 ...
# 16216  2018.0  56009        NaN        NaN                 NaN
# 16217  2015.0  20187        NaN        NaN                 NaN
# 16218  2017.0  31069        NaN        NaN                 NaN
# 16219  2018.0  08061        NaN        NaN                 NaN
# 16220  2018.0  30007        NaN        NaN                 NaN
#
#        tot_srvcs_chrg          reference_period state      county state_fips  \
# 0             1980.00                       NaN   NaN         NaN        NaN
# ...

# %%
state_df = temp_df[['state_fips','state']]
state_df['state_fips'] = [str(i)[:2] for i in state_df['fips']]
# Out:
# /var/folders/ff/7xvchf4558v3w_jjs11bdwlw0000gp/T/ipykernel_37278/2038658304.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   state_df['state_fips'] = [str(i)[:2] for i in state_df['fips']]

# %%
state_df
# Out:
#         fips state state_fips
# 0      01021   NaN         01
# 1      01069   NaN         01
# 2      01073   NaN         01
# 3      01101   NaN         01
# 4      01127   NaN         01
# ...      ...   ...        ...
# 16216  56009    WY         56
# 16217  20187    KS         20
# 16218  31069    NE         31
# 16219  08061    CO         08
# 16220  30007    MT         30
#
# [16221 rows x 3 columns]

# %%
temp_df[temp_df['year']>=2014].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16023 entries, 198 to 16220
# Data columns (total 24 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   year                                     16023 non-null  float64
#  1   fips                                     16023 non-null  int64
#  2   tot_benes                                2389 non-null   float64
#  3   tot_srvcs                                2389 non-null   float64
#  4   tot_bene_day_srvcs                       2389 non-null   float64
#  5   tot_srvcs_chrg                           2389 non-null   float64
#  6   reference_period                         15510 non-null  object
#  7   state                                    15510 non-null  object
#  8   county                                   15510 non-null  object
#  9   state_fips                               15510 non-null  float64
# ...

# %%
amb_df
# Out:
#                reference_period   fips state      county  state_fips  \
# 0      2014-10-01 to 2015-09-30   1001    AL     Autauga           1
# 1      2014-10-01 to 2015-09-30   1003    AL     Baldwin           1
# 2      2014-10-01 to 2015-09-30   1005    AL     Barbour           1
# 3      2014-10-01 to 2015-09-30   1007    AL        Bibb           1
# 4      2014-10-01 to 2015-09-30   1009    AL      Blount           1
# ...                         ...    ...   ...         ...         ...
# 15505  2018-10-01 to 2019-09-30  56009    WY    Converse          56
# 15506  2015-10-01 to 2016-09-30  20187    KS     Stanton          20
# 15507  2017-10-01 to 2018-09-30  31069    NE      Garden          31
# 15508  2018-10-01 to 2019-09-30   8061    CO       Kiowa           8
# 15509  2018-10-01 to 2019-09-30  30007    MT  Broadwater          30
#
#        county_fips  number_of_fee_for_service_beneficiaries    year  \
# 0                1                                     7405  2014.0
# ...

# %%
tele_df
# Out:
#       year   fips  tot_benes  tot_srvcs  tot_bene_day_srvcs  tot_srvcs_chrg
# 0     2013   1021         61         66                  66         1980.00
# 1     2013   1069        467        976                 976        30330.08
# 2     2013   1073         47         85                  85         3149.00
# 3     2013   1101         12         14                  14          350.00
# 4     2013   1127         49        110                 110         4510.00
# ...    ...    ...        ...        ...                 ...             ...
# 2582  2019  56013         62         99                  99         3960.00
# 2583  2019  56021        114        230                 230         7590.00
# 2584  2019  56025        290        321                 321        11271.00
# 2585  2019  56029         43         49                  49         1225.00
# 2586  2019  56043         19         58                  58         1914.00
#
# [2587 rows x 6 columns]
